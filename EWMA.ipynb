# %% [markdown]
# <a href="https://colab.research.google.com/github/Saanchi0505/Deep-learning-Practice/blob/main/EWMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/DailyDelhiClimate.csv")
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df = df.drop('humidity',axis=1)
df.head()
# Out:
#          date   meantemp  wind_speed  meanpressure
# 0  2013-01-01  10.000000    0.000000   1015.666667
# 1  2013-01-02   7.400000    2.980000   1017.800000
# 2  2013-01-03   7.166667    4.633333   1018.666667
# 3  2013-01-04   8.666667    1.233333   1017.166667
# 4  2013-01-05   6.000000    3.700000   1016.500000

# %%
df = df.drop('wind_speed',axis=1)
df.head()
# Out:
#          date   meantemp  meanpressure
# 0  2013-01-01  10.000000   1015.666667
# 1  2013-01-02   7.400000   1017.800000
# 2  2013-01-03   7.166667   1018.666667
# 3  2013-01-04   8.666667   1017.166667
# 4  2013-01-05   6.000000   1016.500000

# %%
df = df.drop('meanpressure',axis=1)
df.head()
# Out:
#          date   meantemp
# 0  2013-01-01  10.000000
# 1  2013-01-02   7.400000
# 2  2013-01-03   7.166667
# 3  2013-01-04   8.666667
# 4  2013-01-05   6.000000

# %%
plt.scatter(df['date'],df['meantemp'],color='red')

# %%
x1 = df['meantemp'].ewm(alpha=0.9).mean()
x1
# Out:
# 0       10.000000
# 1        7.636364
# 2        7.213213
# 3        8.521452
# 4        6.252123
#           ...
# 1571    34.403401
# 1572    34.265340
# 1573    33.036534
# 1574    32.891153
# 1575    32.089115
# Name: meantemp, Length: 1576, dtype: float64

# %%
df['ema'] = x1
df.head()
# Out:
#          date   meantemp        ema
# 0  2013-01-01  10.000000  10.000000
# 1  2013-01-02   7.400000   7.636364
# 2  2013-01-03   7.166667   7.213213
# 3  2013-01-04   8.666667   8.521452
# 4  2013-01-05   6.000000   6.252123

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],df['ema'],label='alpha = 0.9',color='black')
plt.legend()
plt.show()
